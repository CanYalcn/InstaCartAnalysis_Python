# %%
# Import libraries
import pandas as pd
import numpy as np
import os

# %%
path = r'C:\Users\ASUS\Instacart Basket Analysis 01.2024'

# %%
# Importing data set orders_products_prior

df_ords_prods_combined = pd.read_pickle(os.path.join(path, '02 Data', 'Prepared Data', 'orders_products_combined.pkl'))

# %%
# Import df_prods
df_prods =  pd.read_csv(os.path.join(path, '02 Data', 'Prepared Data', 'products_checked.csv'), index_col = False)

# %%
#check rows and columns of df_prods
df_prods.shape
# Out:
# (49693, 6)

# %%
df_prods.head()
# Out:
#    Unnamed: 0  product_id                                       product_name  \
# 0           0           1                         Chocolate Sandwich Cookies
# 1           1           2                                   All-Seasons Salt
# 2           2           3               Robust Golden Unsweetened Oolong Tea
# 3           3           4  Smart Ones Classic Favorites Mini Rigatoni Wit...
# 4           4           5                          Green Chile Anytime Sauce
#
#    aisle_id  department_id  prices
# 0        61             19     5.8
# 1       104             13     9.3
# 2        94              7     4.5
# 3        38              1    10.5
# 4         5             13     4.3

# %%
#check rows and columns of df_ords_prods_combined
df_ords_prods_combined.shape
# Out:
# (32434489, 13)

# %%
df_ords_prods_combined.head()
# Out:
#    Unnamed: 0.1  Unnamed: 0  order_id  user_id eval_set  number_of_orders  \
# 0             0           0   2539329        1    prior                 1
# 1             0           0   2539329        1    prior                 1
# 2             0           0   2539329        1    prior                 1
# 3             0           0   2539329        1    prior                 1
# 4             0           0   2539329        1    prior                 1
#
#    orders_day_of_week  time_of_day  days_since_prior_order  product_id  \
# 0                   2            8                     NaN         196
# 1                   2            8                     NaN       14084
# 2                   2            8                     NaN       12427
# 3                   2            8                     NaN       26088
# 4                   2            8                     NaN       26405
#
#    add_to_cart_order  reordered _merge
# 0                  1          0   both
# 1                  2          0   both
# 2                  3          0   both
# 3                  4          0   both
# 4                  5          0   both

# %%
# Drop unnamed columns in df_prods 
df_prods = df_prods.drop(columns = ['Unnamed: 0'])

# %%
# Drop unnamed columns in df_ords_prods_combined (not necessary) 
df_ords_prods_combined = df_ords_prods_combined.drop(columns = ['Unnamed: 0', 'Unnamed: 0.1', '_merge'])

# %%
# create new merged dataframe
df_ords_prods_merged = df_ords_prods_combined.merge(df_prods, on = 'product_id', indicator=True)

# %%
df_ords_prods_merged
# Out:
#           order_id  user_id eval_set  number_of_orders  orders_day_of_week  \
# 0          2539329        1    prior                 1                   2
# 1          2398795        1    prior                 2                   3
# 2           473747        1    prior                 3                   3
# 3          2254736        1    prior                 4                   4
# 4           431534        1    prior                 5                   4
# ...            ...      ...      ...               ...                 ...
# 32434207   1320836   202557    prior                17                   2
# 32434208     31526   202557    prior                18                   5
# 32434209    758936   203436    prior                 1                   2
# 32434210   2745165   203436    prior                 2                   3
# 32434211   3093936   205420    prior                 1                   4
#
#           time_of_day  days_since_prior_order  product_id  add_to_cart_order  \
# 0                   8                     NaN         196                  1
# 1                   7                    15.0         196                  1
# 2                  12                    21.0         196                  1
# 3                   7                    29.0         196                  1
# 4                  15                    28.0         196                  1
# ...               ...                     ...         ...                ...
# 32434207           15                     1.0       43553                  2
# 32434208           11                     3.0       43553                  2
# 32434209            7                     NaN       42338                  4
# 32434210            5                    15.0       42338                 16
# 32434211           14                     NaN       28818                  8
#
#           reordered                   product_name  aisle_id  department_id  \
# 0                 0                           Soda        77              7
# 1                 1                           Soda        77              7
# 2                 1                           Soda        77              7
# 3                 1                           Soda        77              7
# 4                 1                           Soda        77              7
# ...             ...                            ...       ...            ...
# 32434207          1            Orange Energy Shots        64              7
# 32434208          1            Orange Energy Shots        64              7
# 32434209          0          Zucchini Chips, Pesto        50             19
# 32434210          1          Zucchini Chips, Pesto        50             19
# 32434211          0  Hot Oatmeal Multigrain Raisin       130             14
#
#           prices _merge
# 0            9.0   both
# 1            9.0   both
# 2            9.0   both
# 3            9.0   both
# 4            9.0   both
# ...          ...    ...
# 32434207     3.7   both
# 32434208     3.7   both
# 32434209     6.9   both
# 32434210     6.9   both
# 32434211    10.3   both
#
# [32434212 rows x 15 columns]

# %%
#Checking the values in the _merge column
df_ords_prods_merged['_merge'].value_counts()
# Out:
# _merge
# both          32434212
# left_only            0
# right_only           0
# Name: count, dtype: int64

# %%
#Checking the merged shape
df_ords_prods_merged.shape
# Out:
# (32434212, 15)

# %%
#Exporting the newly merged dataframe; Using pickle format
df_ords_prods_merged.to_pickle(os.path.join(path, '02 Data','Prepared Data', 'orders_products_merged.pkl'))
